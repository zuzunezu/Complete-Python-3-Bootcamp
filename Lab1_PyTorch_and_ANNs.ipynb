# %% [markdown]
# <a href="https://colab.research.google.com/github/zuzunezu/Complete-Python-3-Bootcamp/blob/master/Lab1_PyTorch_and_ANNs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# COLLAB LINK: https://drive.google.com/file/d/1qeauWsLCKNDv7VWhjrIHjwHB52ZbGbPS/view?usp=sharing
#
# student number: 1008039187
# student name: Zeina Shaltout

# %% [markdown]
# # Lab 1. PyTorch and ANNs
#
# This lab is a warm up to get you used to the PyTorch programming environment used
# in the course, and also to help you review and renew your knowledge
# of Python and relevant Python libraries.
# The lab must be done individually. Please recall that the
# University of Toronto plagarism rules apply.
#
# By the end of this lab, you should be able to:
#
# 1. Be able to perform basic PyTorch tensor operations.
# 2. Be able to load data into PyTorch
# 3. Be able to configure an Artificial Neural Network (ANN) using PyTorch
# 4. Be able to train ANNs using PyTorch
# 5. Be able to evaluate different ANN configuations
#
# You will need to use numpy and PyTorch documentations for this assignment:
#
# * https://docs.scipy.org/doc/numpy/reference/
# * https://pytorch.org/docs/stable/torch.html
#
# You can also reference Python API documentations freely.
#
#
# ### What to submit
#
# Submit a PDF file containing all your code, outputs, and write-up
# from parts 1-5. You can produce a PDF of your Google Colab file by
# going to `File -> Print` and then save as PDF. The Colab instructions
# has more information.
#
# **Do not submit any other files produced by your code.**
#
# Include a link to your colab file in your submission.
#
# Please use Google Colab to complete this assignment. If you want to use Jupyter Notebook, please complete the assignment and upload your Jupyter Notebook file to Google Colab for submission.
#
# **Adjust the scaling to ensure that the text is not cutoff at the margins.**

# %% [markdown]
# ## Colab Link
#
# Submit make sure to include a link to your colab file here
#
# Colab Link: https://drive.google.com/file/d/1qeauWsLCKNDv7VWhjrIHjwHB52ZbGbPS/view?usp=sharing

# %% [markdown]
# ## Part 1. Python Basics [3 pt]
#
# The purpose of this section is to get you used to the
# basics of Python, including working with functions, numbers,
# lists, and strings.
#
# Note that we **will** be checking your code for clarity and efficiency.
#
# If you have trouble with this part of the assignment, please review http://cs231n.github.io/python-numpy-tutorial/

# %% [markdown]
# ### Part (a) -- 1pt
#
# Write a function `sum_of_cubes` that computes the sum of cubes up to `n`. If the input to `sum_of_cubes` invalid (e.g. negative or non-integer `n`), the function should print out `"Invalid input"` and return `-1`.

# %%
def sum_of_cubes(n):
    """Return the sum (1^3 + 2^3 + 3^3 + ... + n^3)

    Precondition: n > 0, type(n) == int

    >>> sum_of_cubes(3)
    36
    >>> sum_of_cubes(1)
    1
    """
    if type(n) != int:
      return -1
    else:
      val = 0
      for i in range(n+1):
        val += i**3
      return val
print(sum_of_cubes(3))
print(sum_of_cubes(1))
# Out:
# 36
# 1

# %% [markdown]
# ### Part (b) -- 1pt
#
# Write a function `word_lengths` that takes a sentence (string), computes the length of each word in that sentence, and returns the length of each word in a list. You can
# assume that words are always separated by a space character `" "`.
#
# Hint: recall the `str.split` function in Python.
# If you arenot sure how this function works, try
# typing `help(str.split)` into a Python shell, or check out https://docs.python.org/3.6/library/stdtypes.html#str.split

# %%
help(str.split)
# Out:
# Help on method_descriptor:
#
# split(self, /, sep=None, maxsplit=-1)
#     Return a list of the substrings in the string, using sep as the separator string.
#
#       sep
#         The separator used to split the string.
#
#         When set to None (the default value), will split on any whitespace
#         character (including \\n \\r \\t \\f and spaces) and will discard
#         empty strings from the result.
#       maxsplit
#         Maximum number of splits (starting from the left).
#         -1 (the default value) means no limit.
#
#     Note, str.split() is mainly useful for data that has been intentionally
#     delimited.  With natural text that includes punctuation, consider using
#     the regular expression module.

# %%
def word_lengths(sentence):
    """Return a list containing the length of each word in
    sentence.

    >>> word_lengths("welcome to APS360!")
    [7, 2, 7]
    >>> word_lengths("machine learning is so cool")
    [7, 8, 2, 2, 4]
    """

    sentList = sentence.split()
    lengths = []
    for i in sentList:
      lengths.append(len(i))
    return lengths

print(word_lengths("welcome to APS360!"))
print(word_lengths("machine learning is so cool"))
# Out:
# [7, 2, 7]
# [7, 8, 2, 2, 4]

# %% [markdown]
# ### Part (c) -- 1pt
#
# Write a function `all_same_length` that takes a sentence (string),
# and checks whether every word in the string is the same length.
# You should call the function `word_lengths` in the body
# of this new function.

# %%
def all_same_length(sentence):
    """Return True if every word in sentence has the same
    length, and False otherwise.

    >>> all_same_length("all same length")
    False
    >>> word_lengths("hello world")
    True
    """
    sent = word_lengths(sentence)
    if not sent: #if the sentence is empty or has no words in it
      return True
    check = sent[0]
    for i in sent:
      if i != check:
        return False
    return True

print( all_same_length("all same length"))
print(word_lengths("hello world"))
# Out:
# False
# [5, 5]

# %% [markdown]
# ## Part 2. NumPy Exercises [5 pt]
#
# In this part of the assignment, you'll be manipulating arrays
# usign NumPy. Normally, we use the shorter name `np` to represent
# the package `numpy`.

# %%
import numpy as np

# %% [markdown]
# ### Part (a) -- 1pt
#
# The below variables `matrix` and `vector` are numpy arrays. Explain what you think `<NumpyArray>.size` and `<NumpyArray>.shape` represent.

# %%
matrix = np.array([[1., 2., 3., 0.5],
                   [4., 5., 0., 0.],
                   [-1., -2., 1., 1.]])
vector = np.array([2., 0., 1., -2.])

# %%
matrix.size
# Out:
# 12

# %%
matrix.shape
# Out:
# (3, 4)

# %%
vector.size
# Out:
# 4

# %%
vector.shape
# Out:
# (4,)

# %% [markdown]
# NumpyArray.size tells you the total number of elements in the array. For example, in this context of a 2D array, if the matrix is a 3x4, then the size will be 12. It will return a single integer value that represents the total count of elements accross all the dimensions of the array. With regards to the context of a 1D array, like a vector, the output will also represent the number of elements in the array (in this case, a vector of length 4 will return 4).

# %% [markdown]
# NumpyArray.shape represents a tuple indicating the size of the array in each dimension. In this context of a 2D array/matrix, the shape would be (rows, columns), indicating how many rows and columns the array has. Furthermore, in the context of a 1D array, or a vector, the shape is (n,), where n is the number of elements in the vector, indicating its length. It can also be thought of the same was as other arrays, where the length of the vector is similar to the number of rows. Overall, the shape attribute is useful for multidimensional arrays (not just 2D), since numpy supports 3D, 4D etc., and suggests the broader utility of the shape attribute.

# %% [markdown]
# ### Part (b) -- 1pt
#
# Perform matrix multiplication `output = matrix x vector` by using
# for loops to iterate through the columns and rows.
# Do not use any builtin NumPy functions.
# Cast your output into a NumPy array, if it isn't one already.
#
# Hint: be mindful of the dimension of output

# %%
output = None

# %%
result = [0] * len(matrix)  # since we are doing 3x4 * 4, the result will be a
#3x1. this initializes the result as the number of rows in the matrix
for i in range(len(matrix)):
    for j in range(len(vector)):  # iterate through each element in the vector
        result[i] += matrix[i][j] * vector[j]  # multiply each value of the
        #vector with each value in the row of the matrix, and store it in the
        #index of the result (which is the same as the row of the index)

# cast output to numpy array
output = np.array(result)

# %%
output
# Out:
# array([ 4.,  8., -3.])

# %% [markdown]
# ### Part (c) -- 1pt
#
# Perform matrix multiplication `output2 = matrix x vector` by using
# the function `numpy.dot`.
#
# We will never actually write code as in
# part(c), not only because `numpy.dot` is more concise and easier to read/write, but also performance-wise `numpy.dot` is much faster (it is written in C and highly optimized).
# In general, we will avoid for loops in our code.

# %%
output2 = None

# %%
output2 = np.dot(matrix, vector)

# %%
output2
# Out:
# array([ 4.,  8., -3.])

# %% [markdown]
# ### Part (d) -- 1pt
#
# As a way to test for consistency, show that the two outputs match.

# %%
outputsMatch = np.array_equal(output, output2)

outputsMatch
# Out:
# True

# %% [markdown]
# ### Part (e) -- 1pt
#
# Show that using `np.dot` is faster than using your code from part (c).
#
# You may find the below code snippit helpful:

# %%
import time

# record the time before running code
start_time = time.time()

# place code to run here
calculate = [0] * len(matrix)  # since we are doing 3x4 * 4, the result will be
#a 3x1. this initializes the result as the number of rows in the matrix
for i in range(len(matrix)):
    for j in range(len(vector)):
    #iterate through each element in the vector
        calculate[i] += matrix[i][j] * vector[j]
        # multiply each value of the vector with each value in the row of
        #the matrix, and store it in the index of the result (which is
        #the same as the row of the index)

output = np.array(calculate)
##############################

# record the time after the code is run
end_time = time.time()

# compute the difference
diff = end_time - start_time
diff
# Out:
# 0.00036907196044921875

# %%
# record the time before running code
start_time = time.time()

# place code to run here
calculate2 = np.dot(matrix, vector)
##############################

# record the time after the code is run
end_time = time.time()

# compute the difference
diff = end_time - start_time
diff
# Out:
# 0.0001723766326904297

# %% [markdown]
# ## Part 3. Images [6 pt]
#
# A picture or image can be represented as a NumPy array of “pixels”,
# with dimensions H × W × C, where H is the height of the image, W is the width of the image,
# and C is the number of colour channels. Typically we will use an image with channels that give the the Red, Green, and Blue “level” of each pixel, which is referred to with the short form RGB.
#
# You will write Python code to load an image, and perform several array manipulations to the image and visualize their effects.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Part (a) -- 1 pt
#
# This is a photograph of a dog whose name is Mochi.
#
# ![alt text](https://drive.google.com/uc?export=view&id=1oaLVR2hr1_qzpKQ47i9rVUIklwbDcews)
#
# Load the image from its url (https://drive.google.com/uc?export=view&id=1oaLVR2hr1_qzpKQ47i9rVUIklwbDcews) into the variable `img` using the `plt.imread` function.
#
# Hint: You can enter the URL directly into the `plt.imread` function as a Python string.

# %%
img = None
import numpy as np
import urllib.request
from PIL import Image


url = "https://drive.google.com/uc?export=view&id=1oaLVR2hr1_qzpKQ47i9rVUIklwbDcews"
response = urllib.request.urlopen(url)
img = np.array(Image.open(response))

#img = np.array(Image.open(urllib.request.urlopen("https://drive.google.com/uc?export=view&id=1oaLVR2hr1_qzpKQ47i9rVUIklwbDcews")))


#plt.axis('off')  # This disables the axes

# %% [markdown]
# ### Part (b) -- 1pt
#
# Use the function `plt.imshow` to visualize `img`.
#
# This function will also show the coordinate system used to identify pixels.
# The origin is at the top left corner, and the first dimension indicates the Y (row) direction,
# and the second dimension indicates the X (column) dimension.

# %%
plt.imshow(img)

# %% [markdown]
# ### Part (c) -- 2pt
#
# Modify the image by adding a constant value of 0.25 to each pixel in the `img` and
# store the result in the variable `img_add`. Note that, since the range for the pixels
# needs to be between [0, 1], you will also need to clip img_add to be in the range [0, 1]
# using `numpy.clip`. Clipping sets any value that is outside of the desired range to the
# closest endpoint. Display the image using `plt.imshow`.

# %%
img_add = None
#clipping in imgae processing is a method used to limit the pixel values of an
#image to a range. adding constant to each pixel is done to adjust brightness,
#but it might cause values outside of the standard range of pixels
#if a pixel goes below 0 or above 1, then it cant be displayed correctly,
#since theyre outside of the range that the image formats and can be displayed.
#clipping sets the values that fall outside this range to the closest boundary
#value
#for ex. if the range is 0,1 then if a pixel is -0.2, itll clip to 0.
# add the 0.25 constant value to each pixel
img_add = img + 0.25

# clip values to be in the range [0, 1]
img_add = np.clip(img_add, 0, 1)

plt.imshow(img_add)
plt.show()

# %% [markdown]
# ### Part (d) -- 2pt
#
# Crop the **original** image (`img` variable) to a 130 x 150 image including Mochi's face. Discard the alpha colour channel (i.e. resulting `img_cropped` should **only have RGB channels**)
#
# Display the image.

# %%
row_start = 15 #start at this pixel
row_end = row_start + 130  # move 130 pixels down from the starting row
col_start = 25 #start at this pixel
col_end = col_start + 150  # movel 150 pixels across from the starting column

img_cropped = img[row_start:row_end, col_start:col_end, :3]  # the :3 at the
#end makes sure that the first three colour channels (RGB) are included in the
# cropped image
#the alpha channel is opacity
plt.imshow(img_cropped)
plt.show()

# %% [markdown]
# ## Part 4. Basics of PyTorch [6 pt]
#
# PyTorch is a Python-based neural networks package. Along with tensorflow, PyTorch is currently one of the most popular machine learning libraries.
#
# PyTorch, at its core, is similar to Numpy in a sense that they both
# try to make it easier to write codes for scientific computing
# achieve improved performance over vanilla Python by leveraging highly optimized C back-end.
# However, compare to Numpy, PyTorch offers much better GPU support and provides many high-level features for machine learning. Technically, Numpy can be used to perform almost every thing PyTorch does. However, Numpy would be a lot slower than PyTorch, especially with CUDA GPU, and it would take more effort to write machine learning related code compared to using PyTorch.

# %%
import torch

# %% [markdown]
# ### Part (a) -- 1 pt
#
# Use the function `torch.from_numpy` to convert the numpy array `img_cropped` into
# a PyTorch tensor. Save the result in a variable called `img_torch`.

# %%
img_torch = None

img_torch = torch.from_numpy(img_cropped)
img_torch
# Out:
# tensor([[[167, 116,  63],
#          [166, 115,  62],
#          [163, 112,  59],
#          ...,
#          [129,  63,  28],
#          [130,  64,  29],
#          [127,  63,  27]],
#
#         [[168, 117,  62],
#          [167, 116,  61],
#          [162, 111,  56],
#          ...,
#          [129,  63,  28],
#          [129,  63,  28],
#          [126,  62,  26]],
#
#         [[168, 117,  60],
#          [166, 115,  58],
#          [161, 111,  52],
#          ...,
#          [126,  61,  23],
#          [124,  59,  21],
#          [122,  58,  20]],
#
#         ...,
#
#         [[167, 109,  63],
#          [165, 107,  61],
#          [158, 100,  54],
#          ...,
#          [173, 144, 112],
#          [170, 140, 106],
#          [167, 137, 101]],
#
#         [[168, 110,  62],
#          [166, 108,  60],
#          [160, 102,  54],
#          ...,
#          [170, 140, 106],
#          [165, 132,  97],
#          [160, 126,  91]],
#
#         [[165, 107,  57],
# ...

# %% [markdown]
# ### Part (b) -- 1pt
#
# Use the method `<Tensor>.shape` to find the shape (dimension and size) of `img_torch`.

# %%
img_torch.shape
# Out:
# torch.Size([130, 150, 3])

# %% [markdown]
# ### Part (c) -- 1pt
#
# How many floating-point numbers are stored in the tensor `img_torch`?

# %%
numElements = img_torch.numel()
numElements
# Out:
# 58500

# %% [markdown]
# ### Part (d) -- 1 pt
#
# What does the code `img_torch.transpose(0,2)` do? What does the expression return?
# Is the original variable `img_torch` updated? Explain.

# %%
img_torch.transpose(0,2)
img_torch
# Out:
# tensor([[[167, 116,  63],
#          [166, 115,  62],
#          [163, 112,  59],
#          ...,
#          [129,  63,  28],
#          [130,  64,  29],
#          [127,  63,  27]],
#
#         [[168, 117,  62],
#          [167, 116,  61],
#          [162, 111,  56],
#          ...,
#          [129,  63,  28],
#          [129,  63,  28],
#          [126,  62,  26]],
#
#         [[168, 117,  60],
#          [166, 115,  58],
#          [161, 111,  52],
#          ...,
#          [126,  61,  23],
#          [124,  59,  21],
#          [122,  58,  20]],
#
#         ...,
#
#         [[167, 109,  63],
#          [165, 107,  61],
#          [158, 100,  54],
#          ...,
#          [173, 144, 112],
#          [170, 140, 106],
#          [167, 137, 101]],
#
#         [[168, 110,  62],
#          [166, 108,  60],
#          [160, 102,  54],
#          ...,
#          [170, 140, 106],
#          [165, 132,  97],
#          [160, 126,  91]],
#
#         [[165, 107,  57],
# ...

# %% [markdown]
# The transpose operation swaps the first and third axes (from 0 to the indexed). In this case, since it is (0,2), this means that it is switching the height and colour channel dimensions.
# This operation does not change the original tensor, but it returns a new tensor with the axes transposed. While the shape of the tensor changes, the data within remains the same.

# %% [markdown]
# ### Part (e) -- 1 pt
#
# What does the code `img_torch.unsqueeze(0)` do? What does the expression return?
# Is the original variable `img_torch` updated? Explain.

# %%
img_torch.unsqueeze(0)
# Out:
# tensor([[[[167, 116,  63],
#           [166, 115,  62],
#           [163, 112,  59],
#           ...,
#           [129,  63,  28],
#           [130,  64,  29],
#           [127,  63,  27]],
#
#          [[168, 117,  62],
#           [167, 116,  61],
#           [162, 111,  56],
#           ...,
#           [129,  63,  28],
#           [129,  63,  28],
#           [126,  62,  26]],
#
#          [[168, 117,  60],
#           [166, 115,  58],
#           [161, 111,  52],
#           ...,
#           [126,  61,  23],
#           [124,  59,  21],
#           [122,  58,  20]],
#
#          ...,
#
#          [[167, 109,  63],
#           [165, 107,  61],
#           [158, 100,  54],
#           ...,
#           [173, 144, 112],
#           [170, 140, 106],
#           [167, 137, 101]],
#
#          [[168, 110,  62],
#           [166, 108,  60],
#           [160, 102,  54],
#           ...,
#           [170, 140, 106],
#           [165, 132,  97],
#           [160, 126,  91]],
#
# ...

# %% [markdown]
# The code here adds an extra dimension at the beginning of the tensor, making it now 4 dimensional. In general, the unsqueeze operation adds an additional dimension to the index specified (since it is 0 in this case, that would be the first index).
# The original img_torch variable is not updated, but returns a new tensor with the additional dimension.

# %% [markdown]
# ### Part (f) -- 1 pt
#
# Find the maximum value of `img_torch` along each colour channel? Your output should be a one-dimensional
# PyTorch tensor with exactly three values.
#
# Hint: lookup the function `torch.max`.

# %%
max_values = torch.max(img_torch.reshape(-1, 3), dim=0).values
#the -1 means that the first dimension is calculated austomatically
#the 3 means that we focus on the first three colour channels
#this flattens the image to list of pixels where each pixel is represented
#by (R,G,B)
#dim=0 means that the func will compute the max value of each column in
#the 2d tensor (max value per channel accross all pixels)
#torchmax gives the named tuple with two elements, values, and indices. values
#is the actual max values, and indices wouldve contained the indices
#of the elements of the max values
max_values
# Out:
# tensor([228, 201, 172], dtype=torch.uint8)

# %% [markdown]
# ## Part 5. Training an ANN [10 pt]
#
# The sample code provided below is a 2-layer ANN trained on the MNIST dataset to identify digits less than 3 or greater than and equal to 3. Modify the code by changing any of the following and observe how the accuracy and error are affected:
#
# - number of training iterations
# - number of hidden units
# - numbers of layers
# - types of activation functions
# - learning rate
#
# Please select at least three different options from the list above. For each option, please select two to three different parameters and provide a table.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import datasets, transforms
import matplotlib.pyplot as plt # for plotting
import torch.optim as optim

torch.manual_seed(1) # set the random seed

# define a 2-layer artificial neural network
class Pigeon(nn.Module):
    def __init__(self):
        super(Pigeon, self).__init__()
        self.layer1 = nn.Linear(28 * 28, 30) #NUMBER HIDDEN UNITS: 30 is the
        # number of hidden units in the first (and only) hidden layer. change
        #30 to change number of hidden units
        #NUMBER OF HIDDEN LAYERS: keep adding more layers here
        self.layer2 = nn.Linear(30, 1) #HIDDEN UNIT ADJUSTMENT
    def forward(self, img):
        flattened = img.view(-1, 28 * 28)
        activation1 = self.layer1(flattened)
        activation1 = F.relu(activation1) #ACTIVATION FUNCTION: Replace F.relu
        #with another function like F.sigmoid or F.tanh
        activation2 = self.layer2(activation1)
        return activation2

pigeon = Pigeon()

# load the data
mnist_data = datasets.MNIST('data', train=True, download=True)
mnist_data = list(mnist_data)
mnist_train = mnist_data[:1000]
mnist_val   = mnist_data[1000:2000]
img_to_tensor = transforms.ToTensor()


# simplified training code to train `pigeon` on the "small digit recognition"
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.SGD(pigeon.parameters(), lr=0.000001, momentum=0.9)#LEARNING
#RATE: lr=0.005 specifies the learning rate. To change the
#learning rate, replace 0.005 with value

for (image, label) in mnist_train:
    # actual ground truth: is the digit less than 3?
    actual = torch.tensor(label < 3).reshape([1,1]).type(torch.FloatTensor)
    # pigeon prediction
    out = pigeon(img_to_tensor(image)) # step 1-2
    # update the parameters based on the loss
    loss = criterion(out, actual)      # step 3
    loss.backward()          # step 4 (compute the updates for each parameter)
    optimizer.step()           # step 4 (make the updates for each parameter)
    optimizer.zero_grad()              # a clean up step for PyTorch

# computing the error and accuracy on the training set
error = 0
for (image, label) in mnist_train:
    prob = torch.sigmoid(pigeon(img_to_tensor(image)))
    if (prob < 0.5 and label < 3) or (prob >= 0.5 and label >= 3):
        error += 1
print("Training Error Rate:", error/len(mnist_train))
print("Training Accuracy:", 1 - error/len(mnist_train))


# computing the error and accuracy on a test set
error = 0
for (image, label) in mnist_val:
    prob = torch.sigmoid(pigeon(img_to_tensor(image)))
    if (prob < 0.5 and label < 3) or (prob >= 0.5 and label >= 3):
        error += 1
print("Test Error Rate:", error/len(mnist_val))
print("Test Accuracy:", 1 - error/len(mnist_val))
# Out:
# ...
# 100%|██████████| 9912422/9912422 [00:00<00:00, 75424348.80it/s]
# Extracting data/MNIST/raw/train-images-idx3-ubyte.gz to data/MNIST/raw
#
# ...
# 100%|██████████| 28881/28881 [00:00<00:00, 22829946.07it/s]
# Extracting data/MNIST/raw/train-labels-idx1-ubyte.gz to data/MNIST/raw
#
# ...
# 100%|██████████| 1648877/1648877 [00:00<00:00, 75289759.05it/s]
# Extracting data/MNIST/raw/t10k-images-idx3-ubyte.gz to data/MNIST/raw
# ...
# 100%|██████████| 4542/4542 [00:00<00:00, 8969175.50it/s]
# Extracting data/MNIST/raw/t10k-labels-idx1-ubyte.gz to data/MNIST/raw
# Training Error Rate: 0.433
# Training Accuracy: 0.567
# Test Error Rate: 0.452
# Test Accuracy: 0.548

# %%
import pandas as pd

data = {
    'Configuration': ['Original', 'Hidden Units: 100', 'Hidden Units: 10',
                      'Activation: Sigmoid', 'Activation: Tanh', 'LR: 0.1',
                      'LR: 0.000001'],
    'Hidden Units': [30, 100, 10, '-', '-', '-', '-'],
    'Activation Type': ['ReLU', '-', '-', 'Sigmoid', 'Tanh', '-', '-'],
    'Learning Rate': [0.005, '-', '-', '-', '-', 0.1, 0.000001],
    'Training Error Rate': [0.036, 0.03, 0.047, 0.073, 0.04, 0.312, 0.433],
    'Training Accuracy': [0.964, 0.97, 0.953, 0.927, 0.96, 0.688, 0.567],
    'Test Error Rate': [0.079, 0.077, 0.104, 0.117, 0.094, 0.297, 0.452],
    'Test Accuracy': [0.921, 0.923, 0.896, 0.883, 0.906, 0.703, 0.548]
}

df = pd.DataFrame(data)

df
# Out:
#          Configuration Hidden Units Activation Type Learning Rate  \
# 0             Original           30            ReLU         0.005
# 1    Hidden Units: 100          100               -             -
# 2     Hidden Units: 10           10               -             -
# 3  Activation: Sigmoid            -         Sigmoid             -
# 4     Activation: Tanh            -            Tanh             -
# 5              LR: 0.1            -               -           0.1
# 6         LR: 0.000001            -               -      0.000001
#
#    Training Error Rate  Training Accuracy  Test Error Rate  Test Accuracy
# 0                0.036              0.964            0.079          0.921
# 1                0.030              0.970            0.077          0.923
# 2                0.047              0.953            0.104          0.896
# 3                0.073              0.927            0.117          0.883
# ...

# %% [markdown]
# ### Part (a) -- 3 pt
# Comment on which of the above changes resulted in the best accuracy on training data? What accuracy were you able to achieve?

# %% [markdown]
# According to the above changes, the one that resulted in the best accuracy on training data is the increase in hidden units (100 hidden units), resulting in a training accuracy of 0.97.
# This indicates that increasing the number of hidden units in the model allowed it to learn more complex patterns in the data and allowing the model to perform better on the training dataset.

# %% [markdown]
# ### Part (b) -- 3 pt
#
#
# Comment on which of the above changes resulted in the best accuracy on testing data? What accuracy were you able to achieve?

# %% [markdown]
# According to the above changes, the one that resulted in the best accuracy on testing data is also the increase in hidden units (100 hidden units), resulting in a testing accuracy of 0.923.
# This indicates that the model will perform best on the training data, and also generalized to the unseen data compared to the rest of the configurations tested.

# %% [markdown]
# ### Part (c) -- 4 pt
# Which model hyperparameters should you use, the ones from (a) or (b)?

# %% [markdown]
# While it is crucial to maximize the performance on training and testing datasets, the primary goal should be to maximize the performance on the testing dataset while ensuring the model does not overfit the training data.
# As a result, prioritizing generalization (testing accuracy) is the main indicator of a model's effectiveness; so one should prioritize the hyperparameters that yield the highest testing accuracy.
# While this is the case, it is also crucial to the training accuracy as well. Ideally, the best model is one that will learn effectively from the training data (high training accuracy), but generalizes well to the testing data;
# resulting in a high testing accuracy. If one set of hyperparamaters gives this balance, then it will be the most favourable. As a result, while testing accuracy is prioritzed, the balance between the two accuracies is most important.
#
# In the case of selecting between a and b, since both scenarios yield the highest accuracy for testing and training with the increase of hidden units to 100, then the hyperparamters that I should use should be hidden units.
# As mentioned, this may not always be the case, and other approaches can be considered when selecting hyperparamaters, as highlighted above.

# %%
print("done!")
# Out:
# done!
